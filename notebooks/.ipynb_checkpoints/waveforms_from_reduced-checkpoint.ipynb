# %%
import pandas as pd
import glob
import pickle
import numpy as np
import matplotlib.pyplot as plt 
import yaml
import os
import sys

plt.style.use("~/evanstyle.mplstyle") #replace with your own or comment

sys.path.append("../")
import CryoAsicAnalysis
import Utilities as Util

# %%
#redfile_sig = "/Volumes/CodeDrive/Gamma_Data_7_16_24/reduced/temp/combined.p"
#redfile_bk = "/Volumes/CodeDrive/Gamma_Data_7_16_24/reduced/6g24pt_bkg/combined.p"
#or on llnl
redfile_sig = "/p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/reduced/6g24pt_sig/combined.p"
redfile_bk = "/p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/reduced/6g24pt_bkg/combined.p"

df_sig = pickle.load(open(redfile_sig, "rb"))[0]
df_bk = pickle.load(open(redfile_bk, "rb"))[0]

# %%
#change to your path
config_path = "/g/g15/angelico/cryo-asic-analysis/config/gamma-post-surg-24.yml"
#config_path = "../config/gamma-post-surg-24.yml"

df = df_bk

#a cut that I want to look at
mask = (df["total_charge"] > 10250) & (df["total_charge"] < 10500) 

#plot N random events from the events that pass this cut
n = 10
df_idxs = np.random.choice(df[mask].index, n)
df_idxs = np.unique(df_idxs)
for idx in df_idxs:
    ev = df[mask].loc[idx]
    filename = ev["filename"]
    evidx = ev["evidx"]
    clusters = ev["clusters"]


    #check if this file is accessible 
    if not os.path.exists(filename):
        print("File not found: ", filename)
        continue


    #load the file
    ca = CryoAsicAnalysis.CryoAsicAnalysis(filename, config_path)
    ca.baseline_subtract()
    print("Number of clusters in event: ", len(clusters))
    for clust in clusters:
        print("Number of pulses in cluster: ", len(clust["charge_pulses"]))
        print("Cluster times: ", end='')
        print([p["t_arrival"] for p in clust["charge_pulses"]])
        print("Pulse integrals: ", end='')
        print([p["integral"] for p in clust["charge_pulses"]])
        print("Pulse amplitudes: ", end='')
        print([p["amp"] for p in clust["charge_pulses"]])
        print("Pulse channels: ", end='')
        print([p["channel"] for p in clust["charge_pulses"]])
        fig, ax = ca.plot_strips_waveforms_separated(evidx, sep=0, show=False)
        pulses = clust["charge_pulses"]
        ts = []
        for p in pulses:
            if(Util.get_channel_type(ca.chmap, p["channel"]) == "x"):
                axidx = 0
            else:
                axidx = 1
            
            ax[axidx].scatter(p["tamp"], p["amp"], s=500)
            ax[axidx].axvline(p["t_arrival"])
            ts.append(p["t_arrival"])
            
            

        for ch in range(64):
            axidx = None
            if(Util.get_channel_type(ca.chmap, ch) == "x"):
                axidx = 0
            else:
                axidx = 1
            if(axidx is None):
                continue

            std = ev["ch{:d} baseline_std".format(ch)]

            ax[axidx].axhspan(-std*3, std*3, alpha=0.4)


        #ax[0].legend()
        ax[0].set_xlim([min(ts) - 5, max(ts) + 5])
        ax[1].set_xlim([min(ts) - 5, max(ts) + 5])
        #ax[0].set_ylim([-10000, 10000])
        #ax[1].set_ylim([-10000, 10000])
        ax[0].set_title("Total charge {:.2f}".format(ev["total_charge"]))
        plt.show()
# Out:
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file470.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  2
# Cluster times: [1123.9924335378323, 1120.1375]
# Pulse integrals: [36088.46369050945, 716.2149537606168]
# Pulse amplitudes: [array(72016.14443222), array(1008.54758795)]
# Pulse channels: [16, 38]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file70.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [933.5008084074374]
# Pulse integrals: [36044.61379538125]
# Pulse amplitudes: [array(72206.16064444)]
# Pulse channels: [16]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file222.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  2
# Cluster times: [1447.9991886409737, 1445.8095238095239]
# Pulse integrals: [36044.61379538125, 540.8153732478128]
# Pulse amplitudes: [array(72118.46085418), array(643.13179521)]
# Pulse channels: [16, 61]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file183.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  3
# Cluster times: [341.001221001221, 342.0625, 342.4166666666667]
# Pulse integrals: [35796.13105632144, -160.7829488034038, -175.39958051280414]
# Pulse amplitudes: [array(71738.42842974), array(-219.24947564), array(-306.9492659)]
# Pulse channels: [16, 53, 55]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file571.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [477.4973630831643]
# Pulse integrals: [36410.02958811626]
# Pulse amplitudes: [array(72440.02675179)]
# Pulse channels: [16]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file518.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [808.4970383986928]
# Pulse integrals: [36205.39674418466]
# Pulse amplitudes: [array(71986.9111688)]
# Pulse channels: [16]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file502.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [1558.499090173878]
# Pulse integrals: [36278.47990273166]
# Pulse amplitudes: [array(72425.41012008)]
# Pulse channels: [16]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file113.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [419.5]
# Pulse integrals: [36000.76390025305]
# Pulse amplitudes: [array(72001.52780051)]
# Pulse channels: [16]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file591.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  2
# Cluster times: [590.9965461194637, 591.4148936170213]
# Pulse integrals: [36146.93021734706, 920.8477976922217]
# Pulse amplitudes: [array(72191.54401273), array(1607.82948803)]
# Pulse channels: [16, 36]

# %%
from scipy.ndimage import gaussian_filter
#change to your path
config_path = "/g/g15/angelico/cryo-asic-analysis/config/gamma-post-surg-24.yml"
#config_path = "../config/gamma-post-surg-24.yml"


#a cut that I want to look at
mask = (df_bk["total_charge"] > 10250) & (df_bk["total_charge"] < 10500) 

#plot N random events from the events that pass this cut
n = 3
df_idxs = np.random.choice(df_bk[mask].index, n)
df_idxs = np.unique(df_idxs)
for idx in df_idxs:
    ev = df_bk[mask].loc[idx]
    filename = ev["filename"]
    evidx = ev["evidx"]
    clusters = ev["clusters"]


    #check if this file is accessible 
    if not os.path.exists(filename):
        print("File not found: ", filename)
        continue


    #load the file
    ca = CryoAsicAnalysis.CryoAsicAnalysis(filename, config_path)
    ca.baseline_subtract()
    chidx_map = np.array(ca.df["Channels"].to_list())[0]
    print("Number of clusters in event: ", len(clusters))
    for clust in clusters:
        print("Number of pulses in cluster: ", len(clust["charge_pulses"]))
        print("Cluster times: ", end='')
        print([p["t_arrival"] for p in clust["charge_pulses"]])
        pulses = clust["charge_pulses"]
        for p in pulses:
            fig, ax = plt.subplots()
            wav = ca.get_wave(evidx, p["channel"])
            wav = Util.ADC_to_ENC(wav, ca.config["gain"], ca.config["pt"])
            ax.plot(ca.times, wav, 'ko-')
            filt = gaussian_filter(wav, 0)
            ax.plot(ca.times, filt, 'ro-')
            ax.axhline(ev["ch16 baseline_std"])

    
            ax.set_xlim([p["t_arrival"] - 5, p["t_arrival"] + 5])
        plt.show()
# Out:
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file548.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  2
# Cluster times: [1802.00141815235, 1798.35]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file410.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [405.5]
# loading the waveform dataframe from  /p/lustre1/nexouser/data/StanfordData/ChargeModule/LXe_Run1/Gamma_Data_7_16_24/prereduced/6g24pt_bkg/Source_Retracted_Background_Data_5kV_7_16_24_initcryo_4_6g_24pt_1000us_file593.p
# Done loading
# Number of clusters in event:  1
# Number of pulses in cluster:  1
# Cluster times: [81.50581395348837]
